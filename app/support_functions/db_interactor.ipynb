# %%
from app.support_functions.db_interaction import DatabaseInteractor
import os
from dotenv import load_dotenv
import pandas as pd

# %%
# Load variables from .env
load_dotenv()

# Fetch the URL
db_url = os.getenv("ERROR_LOGS_DB_URL")


db = DatabaseInteractor(db_url=db_url)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 8
#       4 # Fetch the URL
#       5 db_url = os.getenv("ERROR_LOGS_DB_URL")
# ----> 8 db = DatabaseInteractor(db_url=db_url,connect_args={"check_same_thread": False})
#
# TypeError: DatabaseInteractor.__init__() got an unexpected keyword argument 'connect_args'
