# %%
from app.support_functions.db_interaction import DatabaseInteractor
import sqlalchemy as sa
import os
from dotenv import load_dotenv
from app.database.models.errors import ErrorLog
# import pandas as pd

# %%
# Load variables from .env
load_dotenv()

# Fetch the URL
db_url = os.getenv("ERROR_LOGS_DB_URL")


db = DatabaseInteractor(db_url=db_url)

# %%
# Define the database structure


# Create the error table  if it doesn't exist
# schema = [
#     sa.Column("id", sa.Integer(), primary_key=True),
#     sa.Column("timestamp", sa.DateTime()),
#     sa.Column("error_message", sa.Text()),
#     sa.Column("stack_trace", sa.Text())
# ]
ErrorLog()
db.create_table()
# Out:
# Database tables synced successfully.

# %%
db.delete_table(table_name="error_logs")
# Out:
# Error deleting table: error_logs
# ---------------------------------------------------------------------------
# NoSuchTableError                          Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 db.delete_table(table_name="error_logs")
#
# File ~/Documents/GitHub/AI-DATA-ASSISTANT/app/support_functions/db_interaction.py:79, in DatabaseInteractor.delete_table(self, table_name)
#      77 try:
#      78     metadata = sa.MetaData()
# ---> 79     table = sa.Table(table_name, metadata, autoload_with=self.engine)
#      80     table.drop(self.engine)
#      81     print(f"Table '{table_name}' deleted successfully.")
#
# File <string>:2, in __new__(cls, *args, **kw)
#
# File ~/Documents/GitHub/AI-DATA-ASSISTANT/venv/lib/python3.11/site-packages/sqlalchemy/util/deprecations.py:281, in deprecated_params.<locals>.decorate.<locals>.warned(fn, *args, **kwargs)
#     274     if m in kwargs:
#     275         _warn_with_version(
#     276             messages[m],
# ...

# %%
db.insert_data(
    table_name="error_logs",
    data={
        "timestamp": sa.func.now(),
        "error_message": "Sample error message",
        "stack_trace": "Sample stack trace"
    }
)
# Out:
# Error inserting data: error_logs
# ---------------------------------------------------------------------------
# NoSuchTableError                          Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 db.insert_data(
#       2     table_name="error_logs",
#       3     data={
#       4         "timestamp": sa.func.now(),
#       5         "error_message": "Sample error message",
#       6         "stack_trace": "Sample stack trace"
#       7     }
#       8 )
#
# File ~/Documents/GitHub/AI-DATA-ASSISTANT/app/support_functions/db_interaction.py:59, in DatabaseInteractor.insert_data(self, table_name, data)
#      57 with self.engine.connect() as conn:
#      58     metadata = sa.MetaData()
# ---> 59     table = sa.Table(table_name, metadata, autoload_with=self.engine)
#      60     ins = table.insert().values(**data)
#      61     conn.execute(ins)
#
# File <string>:2, in __new__(cls, *args, **kw)
#
# ...

# %%
query = """
SELECT * FROM error_logs

"""
result = db.execute_query(query)
# Out:
# [Error]: (sqlite3.OperationalError) no such table: error_logs
# [SQL:
# SELECT * FROM error_logs
#
# ]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/Documents/GitHub/AI-DATA-ASSISTANT/venv/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#
# File ~/Documents/GitHub/AI-DATA-ASSISTANT/venv/lib/python3.11/site-packages/sqlalchemy/engine/default.py:952, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
# ...
