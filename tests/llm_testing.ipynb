# %% [markdown]
# # LLM Model Testing & Understanding

# %%
PROMPT = """Write a story to inspire greatness, take the antagonist as a Rabbit and protagnist as turtle. 
Let antagonist and protagnist compete against each other for a common goal. 
Story should atmost have 3 lines."""

# %%
# OpenAI Model
from openai import OpenAI
from dotenv import load_dotenv
import os
load_dotenv()

load_dotenv("config/.env")


client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))   
response = client.Completion.create(engine="text-davinci-003", prompt=PROMPT, max_tokens=5)
response_text = response.choices[0].text.strip()
print(response_text)
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[4], line 10
#       5 load_dotenv()
#       7 load_dotenv("config/.env")
# ---> 10 client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))
#      11 response = client.Completion.create(engine="text-davinci-003", prompt=PROMPT, max_tokens=5)
#      12 response_text = response.choices[0].text.strip()
#
# File ~/Documents/GitHub/AI-DATA-ASSISTANT/venv/lib/python3.11/site-packages/openai/_client.py:139, in OpenAI.__init__(self, api_key, organization, project, webhook_secret, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     137     api_key = os.environ.get("OPENAI_API_KEY")
#     138 if api_key is None:
# --> 139     raise OpenAIError(
# ...
